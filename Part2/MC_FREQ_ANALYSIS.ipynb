# %% [markdown]
# # MC Frequency Analysis
# This notebook contains code to perform the "expected distribution" calculations as part of the Chi-Square stats test procedure.  This is Part 2 (See MC_FREQ_SQL.ipynb for Part 1).
#
# In this part, we read the data from csv files and then use it to simulate race results for $n=10,000$ seasons.  We are interested in counting how many times each school does the following:<p>
# 1  Finishes first in state meet <p>
# 2  Finishes 2nd in state meet <p>
# 3  ... <p>
# 20  Finishes 20th in state meet <p>
# 21  Makes it to Districts, but not Regionals <p>
# 22  Makes it to Regionals, but not states <p>
#
# We store the results of the simulation in 20 separate CSV files which can be used to do the actual calculation of expected results.

# %%
import pandas as pd
import numpy as np
import math
import random

# %% [markdown]
# ### Global Parameters
# The cell below sets the important global parameters for div, year and gender.  The user can vary these over
#
# - year: 2017-2021
# - div: 1,2,3
# - gender: 'B', 'G'

# %%
year = 2021
gender = 'G'
div = 3

filename = 'D{0}_{1}_{2}.csv'.format(div,gender,year)
df = pd.read_csv(filename,index_col=0)
print(df)
# Out:
#      BLDG_IRN                          NAME  YEAR  DIVISION GENDER      TYPE  \
# 0       97923        East Dayton Christian   2021         3      G  District
# 1      126144  Granville Christian Academy   2021         3      G  District
# 2      134619   Emmanuel Christian Academy   2021         3      G  District
# 3       13870     Fayette Jr/Sr High School  2021         3      G  District
# 4       15172   Hardin Northern High School  2021         3      G  District
# ..        ...                           ...   ...       ...    ...       ...
# 219     52969              Elyria Catholic   2021         3      G  District
# 220     53934                     Ursuline   2021         3      G  District
# 221     52993              Gilmour Academy   2021         3      G  District
# 222     52993              Gilmour Academy   2021         3      G  Regional
# 223     52993              Gilmour Academy   2021         3      G     State
#
#      PLACE  POPULATION
# 0       17          79
# 1        9          86
# 2       14         104
# 3        5         109
# 4        7         112
# ..     ...         ...
# 219     11         458
# 220      8         464
# 221      1         497
# 222      1         497
# 223      4         497
#
# [224 rows x 8 columns]

# %%
# Create scoring sheet
IDs = df.BLDG_IRN.to_list()
#print(IDs)
scores = {}
for id in IDs:
    scores[id] = [0 for i in range(22)]

# %%
def createDistricts (df):
    '''
    This function takes a data frame df as input and returns another dataframe with district
    assignments.  
    The original df must have a column for BLDG_IRN that uniquely identifies the building ID.
    The returned df has the same columns but now adds a column for DISTRICT # which is a number
    between 0 and 11 (12 districts).  These are randomly assigned to schools.  
    '''
    # get list of BLDG_IRN (unique ids)
    bldgs = df['BLDG_IRN'].tolist()
    bldgs = list(dict.fromkeys(bldgs))
    #print(bldgs)
    n = len(bldgs)
    print(n)

    # create random assignments to 12 different districts
    perms = np.random.permutation(n)
    dists = {}
    for i in range(n):
        idx = perms[i]
        dists[bldgs[idx]] = (i % 12)
    #print(dists)

    # add district into dataframe
    df2 = df.copy()
    df2['DISTRICT'] = -1
    df2['REGION'] = -1
    #print(df2)

    for key in dists:
        val = dists[key]
        df2.loc[df2['BLDG_IRN'] == key,'DISTRICT'] = val % 3
        df2.loc[df2['BLDG_IRN'] == key,'REGION'] = (val // 3) 

    #print(df2)
    return df2

def createDict (df):
    '''
    This function takes a dataframe as input.  It returns a dictionary.
    df: must have column BLDG_IRN that is unique
        must have column POPULATION 
    dictionary:
        key = unique BLDG_IRN
        value = population
    '''
    return dict(zip(df.BLDG_IRN, df.POPULATION))

# %%
df2 = createDistricts(df)
print(df2)
# Out:
# 142
#      BLDG_IRN                          NAME  YEAR  DIVISION GENDER      TYPE  \
# 0       97923        East Dayton Christian   2021         3      G  District
# 1      126144  Granville Christian Academy   2021         3      G  District
# 2      134619   Emmanuel Christian Academy   2021         3      G  District
# 3       13870     Fayette Jr/Sr High School  2021         3      G  District
# 4       15172   Hardin Northern High School  2021         3      G  District
# ..        ...                           ...   ...       ...    ...       ...
# 219     52969              Elyria Catholic   2021         3      G  District
# 220     53934                     Ursuline   2021         3      G  District
# 221     52993              Gilmour Academy   2021         3      G  District
# 222     52993              Gilmour Academy   2021         3      G  Regional
# 223     52993              Gilmour Academy   2021         3      G     State
#
#      PLACE  POPULATION  DISTRICT  REGION
# 0       17          79         0       0
# 1        9          86         1       3
# 2       14         104         2       3
# 3        5         109         0       3
# 4        7         112         2       1
# ..     ...         ...       ...     ...
# 219     11         458         0       2
# 220      8         464         1       2
# 221      1         497         2       2
# 222      1         497         2       2
# 223      4         497         2       2
#
# [224 rows x 10 columns]

# %%
def permSelect (dct):
    '''
    This algorithm performs a weighted selection of a permutation of items.
    The dct parameter is a dictionary
        keys = unique IDs
        values = weights with those IDs
    The return value is a permutation (list) of the keys in an order uniquely determined by
    the weights.  
    '''
    df = pd.DataFrame.from_dict(dct, orient='index')
    df.columns = ['w']
    
    p = []  # empty permutation
    count = 0
    while len(df) > 0:
        total = df.w.sum()
        idx = random.randint(1,total)
        #print('iteration ',count)
        count = count + 1
        #print(df)
        #print('total/idx = ',total,idx)
        k = 0
        while k < len(df) and idx > df.w.iloc[k]:
            idx = idx - df.w.iloc[k]
            k = k + 1
        idx = df.index[k]
        p.append(idx)
        df = df.drop([idx])
        #print('p =',p)

    return p

# %%
# This code will simulate one season of competition for the schools in df
def oneSeason (df,scores):
    '''
    The input is a dataframe that must have columns for
    BLDG_IRN - the unique building id
    POPULATON - the number of students in the population
    
    The scores is a dictionary with BLDG_IRN as the key 
    and the value is an array of 22 integers.  Depending on where
    a team ends up, they increment the count in the appropriate array spot:
        spots 0 to 19 (places 1 to 20 in state meet)
        spot 20 (stopped at regionals)
        spot 21 (stopped at states)
    '''
    st_dct = {}
    for region in range(4):
        rg_dct = {}
        for district in range(3):
            # select teams from correct region and district
            dftemp = df2.loc[(df2['REGION']==region)&(df2['DISTRICT']==district)]
            #print(region,district,dftemp)
            
            # simulate district race
            dct = createDict (dftemp)
            #print(region,district,dct)
            res = permSelect(dct)
            #print(region,district,'results =',res)
            
            # top five go through to regionals
            for i in range(5):
                id = res[i]
                rg_dct[id] = dct[id]
            
            # the rest get score 21 (stop at districts)
            for id in res[5:]:
                scores[id][21] += 1
        # now have regional race
        #print("regional race",region,rg_dct)
        res = permSelect(rg_dct)
        #print(region,'*results =',res)
        
        # top five go to states
        for i in range(5):
            id = res[i]
            st_dct[id] = rg_dct[id]
        
        # rest of score of 20 (stop at regionals)
        for id in res[5:]:
            scores[id][20] += 1
        
    # now simulate state meet
    res = permSelect(st_dct)
    #print('***results =',res)
    for i in range(len(res)):
        id = res[i]
        scores[id][i] += 1

# %%
# This is the main block of code which runs the simulation

n = 10000   # n=10,000 seasons of simulation
for i in range(n):
    if i % 100 == 0:
        print('iteration:',i)
    oneSeason(df2,scores)
#print(scores)
# Out:
# iteration: 0

# %%
# Record the resulst in the corresponding .txt file of the same name.

filename = 'D{0}_{1}_{2}.txt'.format(div,gender,year)
fp = open(filename,'w')
for ID in scores:
    fp.write('{0:6d} '.format(ID))
    print('ID: ',ID)
    df3 = df[((df.BLDG_IRN == ID) & (df.TYPE == 'District'))]
    print(df3)
    pop = int(df3.POPULATION)
    fp.write('{0:8d} '.format(pop))
    for i in range(22):
        fp.write('{0:7d} '.format(scores[ID][i]))
    fp.write('\n')
fp.close()
# Out:
# ID:  97923
#    BLDG_IRN                    NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 0     97923  East Dayton Christian   2021         3      G  District     17
#
#    POPULATION
# 0          79
# ID:  126144
#    BLDG_IRN                          NAME  YEAR  DIVISION GENDER      TYPE  \
# 1    126144  Granville Christian Academy   2021         3      G  District
#
#    PLACE  POPULATION
# 1      9          86
# ID:  134619
#    BLDG_IRN                         NAME  YEAR  DIVISION GENDER      TYPE  \
# 2    134619  Emmanuel Christian Academy   2021         3      G  District
#
#    PLACE  POPULATION
# 2     14         104
# ID:  13870
#    BLDG_IRN                       NAME  YEAR  DIVISION GENDER      TYPE  \
# 3     13870  Fayette Jr/Sr High School  2021         3      G  District
#
#    PLACE  POPULATION
# 3      5         109
# ID:  15172
#    BLDG_IRN                         NAME  YEAR  DIVISION GENDER      TYPE  \
# 4     15172  Hardin Northern High School  2021         3      G  District
#
#    PLACE  POPULATION
# 4      7         112
# ID:  3376
#    BLDG_IRN                  NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 5      3376  Bradford High School  2021         3      G  District     16
#
#    POPULATION
# 5         116
# ID:  33050
#    BLDG_IRN                NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 6     33050  Russia High School  2021         3      G  District      8
#
#    POPULATION
# 6         117
# ID:  40097
#    BLDG_IRN                                  NAME  YEAR  DIVISION GENDER  \
# 7     40097  Waynesfield-Goshen Local High School  2021         3      G
#
#        TYPE  PLACE  POPULATION
# 7  District      5         126
# ID:  16568
#    BLDG_IRN                 NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 8     16568  Holgate High School  2021         3      G  District      2
#
#    POPULATION
# 8         128
# ID:  52670
#     BLDG_IRN                   NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 10     52670  Wm V Fisher Catholic   2021         3      G  District      5
#
#     POPULATION
# 10         138
# ID:  14373
#     BLDG_IRN               NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 11     14373  Green High School  2021         3      G  District     11
#
#     POPULATION
# 11         140
# ID:  29793
#     BLDG_IRN                     NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 12     29793  Pettisville High School  2021         3      G  District      1
#
#     POPULATION
# 12         141
# ID:  42333
#     BLDG_IRN                         NAME  YEAR  DIVISION GENDER      TYPE  \
# 14     42333  Western Reserve High School  2021         3      G  District
#
#     PLACE  POPULATION
# 14      7         145
# ID:  15099
#     BLDG_IRN                      NAME  YEAR  DIVISION GENDER      TYPE  \
# 15     15099  South Gallia High School  2021         3      G  District
#
#     PLACE  POPULATION
# 15     14         146
# ID:  36244
#     BLDG_IRN                            NAME  YEAR  DIVISION GENDER      TYPE  \
# 16     36244  Strasburg-Franklin High School  2021         3      G  District
#
#     PLACE  POPULATION
# 16      6         148
# ID:  12377
#     BLDG_IRN                         NAME  YEAR  DIVISION GENDER      TYPE  \
# 17     12377  Franklin Monroe High School  2021         3      G  District
#
#     PLACE  POPULATION
# 17     15         153
# ID:  67637
#     BLDG_IRN                      NAME  YEAR  DIVISION GENDER      TYPE  \
# 18     67637  The Miami Valley School   2021         3      G  District
#
#     PLACE  POPULATION
# 18      6         153
# ID:  134510
#     BLDG_IRN                          NAME  YEAR  DIVISION GENDER      TYPE  \
# 19    134510  Fairfield Christian Academy   2021         3      G  District
#
#     PLACE  POPULATION
# 19      3         157
# ID:  25361
#     BLDG_IRN                     NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 21     25361  Monroeville High School  2021         3      G  District      8
#
#     POPULATION
# 21         162
# ID:  5173
#     BLDG_IRN                    NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 22      5173  Cedarville High School  2021         3      G  District      7
#
#     POPULATION
# 22         165
# ID:  844
#     BLDG_IRN                       NAME  YEAR  DIVISION GENDER      TYPE  \
# 24       844  Antwerp Local High School  2021         3      G  District
#
#     PLACE  POPULATION
# 24      6         174
# ID:  4085
#     BLDG_IRN                         NAME  YEAR  DIVISION GENDER      TYPE  \
# 25      4085  Buckeye Central High School  2021         3      G  District
#
#     PLACE  POPULATION
# 25      9         174
# ID:  53645
#     BLDG_IRN                                 NAME  YEAR  DIVISION GENDER  \
# 26     53645  St John Elementary and High School   2021         3      G
#
#         TYPE  PLACE  POPULATION
# 26  District      3         174
# ID:  81851
#     BLDG_IRN               NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 28     81851  Toledo Christian   2021         3      G  District      7
#
#     POPULATION
# 28         175
# ID:  9894
#     BLDG_IRN                  NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 29      9894  Edgerton High School  2021         3      G  District      5
#
#     POPULATION
# 29         179
# ID:  3228
#     BLDG_IRN                 NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 30      3228  Botkins High School  2021         3      G  District      6
#
#     POPULATION
# 30         183
# ID:  22368
#     BLDG_IRN                 NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 32     22368  Malvern High School  2021         3      G  District      8
#
#     POPULATION
# 32         183
# ID:  23218
#     BLDG_IRN                 NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 33     23218  Mathews High School  2021         3      G  District      9
#
#     POPULATION
# 33         184
# ID:  36749
#     BLDG_IRN                       NAME  YEAR  DIVISION GENDER      TYPE  \
# 34     36749  Symmes Valley High School  2021         3      G  District
#
#     PLACE  POPULATION
# 34     13         189
# ID:  15156
#     BLDG_IRN                 NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 35     15156  Houston High School  2021         3      G  District     13
#
#     POPULATION
# 35         192
# ID:  34090
#     BLDG_IRN                   NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 36     34090  Shadyside High School  2021         3      G  District      9
#
#     POPULATION
# 36         194
# ID:  778
#     BLDG_IRN                 NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 37       778  Ansonia High School  2021         3      G  District     12
#
#     POPULATION
# 37         195
# ID:  12641
#     BLDG_IRN                                    NAME  YEAR  DIVISION GENDER  \
# 38     12641  Fort Loramie Junior-Senior High School  2021         3      G
#
#         TYPE  PLACE  POPULATION
# 38  District      1         197
# ID:  22681
#     BLDG_IRN                   NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 41     22681  Maplewood High School  2021         3      G  District      2
#
#     POPULATION
# 41         197
# ID:  7534
#     BLDG_IRN                   NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 43      7534  Covington High School  2021         3      G  District     10
#
#     POPULATION
# 43         199
# ID:  53769
#     BLDG_IRN                      NAME  YEAR  DIVISION GENDER      TYPE  \
# 44     53769  Norwalk Catholic School   2021         3      G  District
#
#     PLACE  POPULATION
# 44      4         207
# ID:  4556
#     BLDG_IRN                  NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 46      4556  Caldwell High School  2021         3      G  District      2
#
#     POPULATION
# 46         208
# ID:  53355
#     BLDG_IRN              NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 49     53355  Newark Catholic   2021         3      G  District      7
#
#     POPULATION
# 49         209
# ID:  2873
#     BLDG_IRN                             NAME  YEAR  DIVISION GENDER  \
# 50      2873  South Webster Jr/Sr High School  2021         3      G
#
#         TYPE  PLACE  POPULATION
# 50  District      3         209
# ID:  25148
#     BLDG_IRN                  NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 52     25148  Mogadore High School  2021         3      G  District      1
#
#     POPULATION
# 52         212
# ID:  25437
#     BLDG_IRN                    NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 54     25437  Montpelier High School  2021         3      G  District      7
#
#     POPULATION
# 54         213
# ID:  31831
#     BLDG_IRN                 NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 55     31831  Rittman High School  2021         3      G  District      2
#
#     POPULATION
# 55         214
# ID:  26823
#     BLDG_IRN                    NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 58     26823  New London High School  2021         3      G  District      5
#
#     POPULATION
# 58         217
# ID:  29025
#     BLDG_IRN                      NAME  YEAR  DIVISION GENDER      TYPE  \
# 59     29025  Paint Valley High School  2021         3      G  District
#
#     PLACE  POPULATION
# 59     10         219
# ID:  90209
#     BLDG_IRN                    NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 60     90209  The Wellington School   2021         3      G  District     10
#
#     POPULATION
# 60         221
# ID:  28506
#     BLDG_IRN                  NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 61     28506  Old Fort High School  2021         3      G  District      1
#
#     POPULATION
# 61         222
# ID:  23515
#     BLDG_IRN                  NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 63     23515  McDonald High School  2021         3      G  District      4
#
#     POPULATION
# 63         224
# ID:  8433
#     BLDG_IRN                       NAME  YEAR  DIVISION GENDER      TYPE  \
# 66      8433  Patrick Henry High School  2021         3      G  District
#
#     PLACE  POPULATION
# 66      4         224
# ID:  7666
#     BLDG_IRN                   NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 67      7666  Crestview High School  2021         3      G  District      6
#
#     POPULATION
# 67         226
# ID:  60806
#     BLDG_IRN                        NAME  YEAR  DIVISION GENDER      TYPE  \
# 68     60806  Maumee Valley Country Day   2021         3      G  District
#
#     PLACE  POPULATION
# 68      8         230
# ID:  21519
#     BLDG_IRN                     NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 69     21519  Loudonville High School  2021         3      G  District      4
#
#     POPULATION
# 69         238
# ID:  112227
#     BLDG_IRN                   NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 71    112227  Grove City Christian   2021         3      G  District      6
#
#     POPULATION
# 71         240
# ID:  25155
#     BLDG_IRN                NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 72     25155  Mohawk High School  2021         3      G  District      9
#
#     POPULATION
# 72         243
# ID:  26641
#     BLDG_IRN                    NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 73     26641  New Bremen High School  2021         3      G  District      2
#
#     POPULATION
# 73         244
# ID:  20990
#     BLDG_IRN                           NAME  YEAR  DIVISION GENDER      TYPE  \
# 75     20990  Lincolnview Jr/Sr High School  2021         3      G  District
#
#     PLACE  POPULATION
# 75      6         245
# ID:  42044
#     BLDG_IRN                  NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 76     42044  Woodmore High School  2021         3      G  District      3
#
#     POPULATION
# 76         251
# ID:  22640
#     BLDG_IRN                  NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 78     22640  Mapleton High School  2021         3      G  District      6
#
#     POPULATION
# 78         252
# ID:  24026
#     BLDG_IRN                       NAME  YEAR  DIVISION GENDER      TYPE  \
# 79     24026  Mechanicsburg High School  2021         3      G  District
#
#     PLACE  POPULATION
# 79     11         252
# ID:  6965
#     BLDG_IRN                      NAME  YEAR  DIVISION GENDER      TYPE  \
# 80      6965  Col Crawford High School  2021         3      G  District
#
#     PLACE  POPULATION
# 80      1         253
# ID:  11478
#     BLDG_IRN                         NAME  YEAR  DIVISION GENDER      TYPE  \
# 83     11478  Federal Hocking High School  2021         3      G  District
#
#     PLACE  POPULATION
# 83      6         253
# ID:  25114
#     BLDG_IRN                       NAME  YEAR  DIVISION GENDER      TYPE  \
# 84     25114  Minster Jr/Sr High School  2021         3      G  District
#
#     PLACE  POPULATION
# 84      1         257
# ID:  66555
#     BLDG_IRN                      NAME  YEAR  DIVISION GENDER      TYPE  \
# 87     66555  Dayton Christian School   2021         3      G  District
#
#     PLACE  POPULATION
# 87      5         260
# ID:  29470
#     BLDG_IRN                     NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 88     29470  Wayne Trace High School  2021         3      G  District      7
#
#     POPULATION
# 88         260
# ID:  16816
#     BLDG_IRN                               NAME  YEAR  DIVISION GENDER  \
# 89     16816  Hopewell-Loudon Local High School  2021         3      G
#
#         TYPE  PLACE  POPULATION
# 89  District      7         261
# ID:  8961
#     BLDG_IRN                     NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 90      8961  East Canton High School  2021         3      G  District      6
#
#     POPULATION
# 90         262
# ID:  1198
#     BLDG_IRN                     NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 91      1198  Seneca East High School  2021         3      G  District      6
#
#     POPULATION
# 91         263
# ID:  8003
#     BLDG_IRN                NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 92      8003  Dalton High School  2021         3      G  District      3
#
#     POPULATION
# 92         264
# ID:  11056
#     BLDG_IRN                         NAME  YEAR  DIVISION GENDER      TYPE  \
# 94     11056  Fairfield Local High School  2021         3      G  District
#
#     PLACE  POPULATION
# 94      9         264
# ID:  52894
#     BLDG_IRN                     NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 95     52894  Cincinnati Country Day   2021         3      G  District      7
#
#     POPULATION
# 95         265
# ID:  11288
#     BLDG_IRN                  NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 96     11288  Fairview High School  2021         3      G  District      3
#
#     POPULATION
# 96         265
# ID:  7823
#     BLDG_IRN                     NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 98      7823  Crooksville High School  2021         3      G  District      8
#
#     POPULATION
# 98         266
# ID:  13433
#     BLDG_IRN                    NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 99     13433  Gibsonburg High School  2021         3      G  District      5
#
#     POPULATION
# 99         267
# ID:  61317
#      BLDG_IRN                    NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 101     61317  Wellington High School  2021         3      G  District     12
#
#      POPULATION
# 101         267
# ID:  7104
#      BLDG_IRN                        NAME  YEAR  DIVISION GENDER      TYPE  \
# 102      7104  Columbus Grove High School  2021         3      G  District
#
#      PLACE  POPULATION
# 102      8         269
# ID:  29280
#      BLDG_IRN                 NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 103     29280  Parkway High School  2021         3      G  District      3
#
#      POPULATION
# 103         269
# ID:  42341
#      BLDG_IRN                         NAME  YEAR  DIVISION GENDER      TYPE  \
# 105     42341  Western Reserve High School  2021         3      G  District
#
#      PLACE  POPULATION
# 105      7         269
# ID:  22863
#      BLDG_IRN                      NAME  YEAR  DIVISION GENDER      TYPE  \
# 106     22863  Marion Local High School  2021         3      G  District
#
#      PLACE  POPULATION
# 106      4         270
# ID:  12591
#      BLDG_IRN                   NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 107     12591  Fort Frye High School  2021         3      G  District      1
#
#      POPULATION
# 107         271
# ID:  7021
#      BLDG_IRN                  NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 110      7021  Columbia High School  2021         3      G  District      5
#
#      POPULATION
# 110         274
# ID:  25023
#      BLDG_IRN                       NAME  YEAR  DIVISION GENDER      TYPE  \
# 112     25023  Mineral Ridge High School  2021         3      G  District
#
#      PLACE  POPULATION
# 112      3         274
# ID:  27722
#      BLDG_IRN                  NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 115     27722  Northmor High School  2021         3      G  District      4
#
#      POPULATION
# 115         274
# ID:  9134
#      BLDG_IRN                        NAME  YEAR  DIVISION GENDER      TYPE  \
# 116      9134  East Palestine High School  2021         3      G  District
#
#      PLACE  POPULATION
# 116      3         276
# ID:  12849
#      BLDG_IRN                 NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 118     12849  Garaway High School  2021         3      G  District      4
#
#      POPULATION
# 118         280
# ID:  42564
#      BLDG_IRN                       NAME  YEAR  DIVISION GENDER      TYPE  \
# 120     42564  Buckeye Trail High School  2021         3      G  District
#
#      PLACE  POPULATION
# 120      5         282
# ID:  25783
#      BLDG_IRN                   NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 121     25783  Mt Gilead High School  2021         3      G  District      2
#
#      POPULATION
# 121         282
# ID:  33944
#      BLDG_IRN                     NAME  YEAR  DIVISION GENDER      TYPE  \
# 124     33944  North Adams High School  2021         3      G  District
#
#      PLACE  POPULATION
# 124      1         285
# ID:  35659
#      BLDG_IRN                  NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 126     35659  St Henry High School  2021         3      G  District      2
#
#      POPULATION
# 126         285
# ID:  13326
#      BLDG_IRN                          NAME  YEAR  DIVISION GENDER      TYPE  \
# 129     13326  Georgetown Jr/Sr High School  2021         3      G  District
#
#      PLACE  POPULATION
# 129      3         286
# ID:  17160
#      BLDG_IRN                    NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 131     17160  Huntington High School  2021         3      G  District      5
#
#      POPULATION
# 131         286
# ID:  22764
#      BLDG_IRN                    NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 133     22764  Margaretta High School  2021         3      G  District      2
#
#      POPULATION
# 133         289
# ID:  52845
#      BLDG_IRN               NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 136     52845  Central Catholic   2021         3      G  District      5
#
#      POPULATION
# 136         290
# ID:  919
#      BLDG_IRN                 NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 137       919  Arcanum High School  2021         3      G  District      5
#
#      POPULATION
# 137         291
# ID:  7674
#      BLDG_IRN                   NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 139      7674  Crestview High School  2021         3      G  District      2
#
#      POPULATION
# 139         296
# ID:  12674
#      BLDG_IRN                       NAME  YEAR  DIVISION GENDER      TYPE  \
# 142     12674  Fort Recovery High School  2021         3      G  District
#
#      PLACE  POPULATION
# 142      1         299
# ID:  42366
#      BLDG_IRN                 NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 145     42366  Wynford High School  2021         3      G  District      3
#
#      POPULATION
# 145         300
# ID:  4861
#      BLDG_IRN                            NAME  YEAR  DIVISION GENDER  \
# 147      4861  Cardington-Lincoln High School  2021         3      G
#
#          TYPE  PLACE  POPULATION
# 147  District      1         301
# ID:  5298
#      BLDG_IRN                    NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 150      5298  Centerburg High School  2021         3      G  District      4
#
#      POPULATION
# 150         303
# ID:  4887
#      BLDG_IRN               NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 151      4887  Carey High School  2021         3      G  District      6
#
#      POPULATION
# 151         306
# ID:  37275
#      BLDG_IRN                NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 152     37275  Tinora High School  2021         3      G  District      2
#
#      POPULATION
# 152         309
# ID:  752
#      BLDG_IRN              NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 154       752  Anna High School  2021         3      G  District      3
#
#      POPULATION
# 154         311
# ID:  30932
#      BLDG_IRN                           NAME  YEAR  DIVISION GENDER      TYPE  \
# 157     30932  Pymatuning Valley High School  2021         3      G  District
#
#      PLACE  POPULATION
# 157      6         311
# ID:  20297
#      BLDG_IRN                        NAME  YEAR  DIVISION GENDER      TYPE  \
# 158     20297  Liberty Center High School  2021         3      G  District
#
#      PLACE  POPULATION
# 158      1         312
# ID:  38893
#      BLDG_IRN                    NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 161     38893  West Union High School  2021         3      G  District      4
#
#      POPULATION
# 161         312
# ID:  32607
#      BLDG_IRN                                   NAME  YEAR  DIVISION GENDER  \
# 163     32607  Rootstown/Ward Davis Bldg High School  2021         3      G
#
#          TYPE  PLACE  POPULATION
# 163  District      2         314
# ID:  40071
#      BLDG_IRN                   NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 165     40071  Waynedale High School  2021         3      G  District      1
#
#      POPULATION
# 165         317
# ID:  27771
#      BLDG_IRN                    NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 168     27771  Northridge High School  2021         3      G  District      5
#
#      POPULATION
# 168         318
# ID:  8532
#      BLDG_IRN               NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 169      8532  Dixie High School  2021         3      G  District     18
#
#      POPULATION
# 169         319
# ID:  10439
#      BLDG_IRN                 NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 170     10439  Elmwood High School  2021         3      G  District     10
#
#      POPULATION
# 170         323
# ID:  17285
#      BLDG_IRN                      NAME  YEAR  DIVISION GENDER      TYPE  \
# 171     17285  Independence High School  2021         3      G  District
#
#      PLACE  POPULATION
# 171      8         328
# ID:  10926
#      BLDG_IRN                   NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 172     10926  Fairbanks High School  2021         3      G  District      6
#
#      POPULATION
# 172         333
# ID:  3038
#      BLDG_IRN                  NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 173      3038  Bluffton High School  2021         3      G  District      5
#
#      POPULATION
# 173         334
# ID:  14100
#      BLDG_IRN                           NAME  YEAR  DIVISION GENDER      TYPE  \
# 174     14100  Grandview Heights High School  2021         3      G  District
#
#      PLACE  POPULATION
# 174      1         335
# ID:  37911
#      BLDG_IRN                NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 177     37911  United High School  2021         3      G  District      8
#
#      POPULATION
# 177         337
# ID:  34793
#      BLDG_IRN                    NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 178     34793  Smithville High School  2021         3      G  District      7
#
#      POPULATION
# 178         340
# ID:  71001
#      BLDG_IRN                           NAME  YEAR  DIVISION GENDER      TYPE  \
# 179     71001  Worthington Christian School   2021         3      G  District
#
#      PLACE  POPULATION
# 179      8         341
# ID:  10884
#      BLDG_IRN                   NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 180     10884  Evergreen High School  2021         3      G  District      6
#
#      POPULATION
# 180         347
# ID:  38232
#      BLDG_IRN                   NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 181     38232  Van Buren High School  2021         3      G  District      4
#
#      POPULATION
# 181         349
# ID:  13243
#      BLDG_IRN                    NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 183     13243  Genoa Area High School  2021         3      G  District      8
#
#      POPULATION
# 183         352
# ID:  27854
#      BLDG_IRN                   NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 184     27854  Northwest High School  2021         3      G  District     12
#
#      POPULATION
# 184         352
# ID:  28894
#      BLDG_IRN                      NAME  YEAR  DIVISION GENDER      TYPE  \
# 185     28894  Ottawa Hills High School  2021         3      G  District
#
#      PLACE  POPULATION
# 185      4         353
# ID:  26229
#      BLDG_IRN                     NAME  YEAR  DIVISION GENDER      TYPE  \
# 186     26229  South Range High School  2021         3      G  District
#
#      PLACE  POPULATION
# 186      4         354
# ID:  935
#      BLDG_IRN                  NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 188       935  Archbold High School  2021         3      G  District      3
#
#      POPULATION
# 188         357
# ID:  6312
#      BLDG_IRN                          NAME  YEAR  DIVISION GENDER      TYPE  \
# 190      6312  Chippewa Jr./Sr. High School  2021         3      G  District
#
#      PLACE  POPULATION
# 190      9         359
# ID:  38760
#      BLDG_IRN                                   NAME  YEAR  DIVISION GENDER  \
# 191     38760  West Liberty-Salem Middle/High School  2021         3      G
#
#          TYPE  PLACE  POPULATION
# 191  District      2         361
# ID:  28779
#      BLDG_IRN                  NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 194     28779  Orrville High School  2021         3      G  District     10
#
#      POPULATION
# 194         366
# ID:  20420
#      BLDG_IRN                       NAME  YEAR  DIVISION GENDER      TYPE  \
# 195     20420  Liberty Union High School  2021         3      G  District
#
#      PLACE  POPULATION
# 195      2         372
# ID:  53900
#      BLDG_IRN                 NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 197     53900  Summit Country Day   2021         3      G  District      2
#
#      POPULATION
# 197         373
# ID:  1602
#      BLDG_IRN                     NAME  YEAR  DIVISION GENDER      TYPE  \
# 199      1602  Barnesville High School  2021         3      G  District
#
#      PLACE  POPULATION
# 199      3         383
# ID:  52902
#      BLDG_IRN                 NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 201     52902  Seven Hills School   2021         3      G  District      4
#
#      POPULATION
# 201         385
# ID:  38414
#      BLDG_IRN                    NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 203     38414  Versailles High School  2021         3      G  District      4
#
#      POPULATION
# 203         390
# ID:  24372
#      BLDG_IRN                    NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 205     24372  Miami East High School  2021         3      G  District      9
#
#      POPULATION
# 205         394
# ID:  19216
#      BLDG_IRN                  NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 206     19216  Kirtland High School  2021         3      G  District      5
#
#      POPULATION
# 206         395
# ID:  42572
#      BLDG_IRN                    NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 208     42572  Zane Trace High School  2021         3      G  District      7
#
#      POPULATION
# 208         410
# ID:  23036
#      BLDG_IRN                       NAME  YEAR  DIVISION GENDER      TYPE  \
# 209     23036  Martins Ferry High School  2021         3      G  District
#
#      PLACE  POPULATION
# 209      7         414
# ID:  6858
#      BLDG_IRN                   NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 210      6858  Coldwater High School  2021         3      G  District      4
#
#      POPULATION
# 210         415
# ID:  21956
#      BLDG_IRN                 NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 211     21956  Madeira High School  2021         3      G  District      1
#
#      POPULATION
# 211         415
# ID:  52704
#      BLDG_IRN           NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 214     52704  Bishop Ready   2021         3      G  District      3
#
#      POPULATION
# 214         421
# ID:  41202
#      BLDG_IRN                   NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 216     41202  Wickliffe High School  2021         3      G  District      7
#
#      POPULATION
# 216         423
# ID:  40683
#      BLDG_IRN                  NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 217     40683  Westfall High School  2021         3      G  District      2
#
#      POPULATION
# 217         443
# ID:  52969
#      BLDG_IRN              NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 219     52969  Elyria Catholic   2021         3      G  District     11
#
#      POPULATION
# 219         458
# ID:  53934
#      BLDG_IRN       NAME  YEAR  DIVISION GENDER      TYPE  PLACE  POPULATION
# 220     53934  Ursuline   2021         3      G  District      8         464
# ID:  52993
#      BLDG_IRN              NAME  YEAR  DIVISION GENDER      TYPE  PLACE  \
# 221     52993  Gilmour Academy   2021         3      G  District      1
#
#      POPULATION
# 221         497
